# %% [markdown]
# # FIFA 20 Player Dataset

# %% [markdown]
# ## Part I)  A) Load the library

# %%
# Import required libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %% [markdown]
# ## Part I) B) Read the data

# %%
# Load the data from your file or data source

# %%
fifa_df=pd.read_csv('players_20.csv')
print('FIFA 20 players')
fifa_df
# Out:
# FIFA 20 players
#        sofifa_id                                         player_url
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...  \
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age
# ...

# %% [markdown]
# The datasets provided include the players data for the Career Mode from FIFA 15 to FIFA 20
# ("players_20.csv"). The data allows multiple comparison of the same players across the last 6
# version of the videogame.
# Some ideas of possible analysis:
# - Historical comparison between Messi and Ronaldo (what skill attributes changed the most
# during time - compared to real-life stats);
# - Ideal budget to create a competitive team (at the level of top n teams in Europe) and at
# which point the budget does not allow to buy significantly better players for the 11-men
# lineup. An extra is the same comparison with the Potential attribute for the lineup instead of
# the Overall attribute;
# - Sample analysis of top n% players (e.g. top 5% of the player) to see if some important
# attributes as Agility or BallControl or Strength have been popular or not acroos the FIFA
# versions. An example would be seeing that the top 5% players of FIFA 20 are more fast
# (higher Acceleration and Agility) compared to FIFA 15. The trend of attributes is also an
# important indication of how some attributes are necessary for players to win games (a
# version with more top 5% players with high BallControl stats would indicate that the game is
# more focused on the technique rather than the physicial aspect).
# Feel free to use the available dataset the way you prefer and do not hesitate to flag additional files
# (player images - datasets prior FIFA 15) that could be implemented to the existing CSV files.
# Updated dataset available here:
# https://www.kaggle.com/stefanoleone992/fifa-21-complete-player-dataset
# - Every player available in FIFA 15, 16, 17, 18, 19, and also FIFA 20
# - 100+ attributes
# - URL of the scraped player
# - Player positions, with the role in the club and in the national team
# - Player attributes with statistics as Attacking, Skills, Defense, Mentality, GK Skills, etc.
# - Player personal data like Nationality, Club, DateOfBirth, Wage, Salary, etc.

# %%
# Show first 5 rows

# %%
fifa_df.head()
# Out:
#    sofifa_id                                         player_url
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...  \
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24  \
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm
# ...

# %%
# Show last 5 rows

# %%
fifa_df.tail()
# Out:
#        sofifa_id                                         player_url
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...  \
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#          short_name     long_name  age         dob  height_cm  weight_kg
# 18273    Shao Shuai            邵帅   22  1997-03-10        186         79  \
# 18274  Xiao Mingjie  Mingjie Xiao   22  1997-01-01        177         66
# 18275     Zhang Wei            张威   19  2000-05-16        186         75
# 18276  Wang Haijian           汪海健   18  2000-08-02        185         74
# 18277    Pan Ximing           潘喜明   26  1993-01-11        182         78
#
#       nationality                           club  ...   lwb   ldm   cdm   rdm
# ...

# %%
# Show the info for data

# %%
fifa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(16), int64(45), object(43)
# memory usage: 14.5+ MB

# %%
# Show the columns

# %%
a=list(fifa_df.columns)
a
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
# ...

# %%
# Check shape and length of data

# %%
fifa_df.shape, len(fifa_df)
# Out:
# ((18278, 104), 18278)

# %%
# Show the description summary for numerical and categorical values.

# %%
fifa_df.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall
# count   18278.000000  18278.000000  18278.000000  18278.000000  18278.000000  \
# mean   219738.864482     25.283291    181.362184     75.276343     66.244994
# std     27960.200461      4.656964      6.756961      7.047744      6.949953
# min       768.000000     16.000000    156.000000     50.000000     48.000000
# 25%    204445.500000     22.000000    177.000000     70.000000     62.000000
# 50%    226165.000000     25.000000    181.000000     75.000000     66.000000
# 75%    240795.750000     29.000000    186.000000     80.000000     71.000000
# max    252905.000000     42.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation
# count  18278.000000  1.827800e+04   18278.000000              18278.000000  \
# mean      71.546887  2.484038e+06    9456.942773                  1.103184
# ...

# %%
fifa_df.describe(include='O')
# Out:
#                                                player_url    short_name
# count                                               18278         18278  \
# unique                                              18278         17354
# top     https://sofifa.com/player/158023/lionel-messi/...  J. Rodríguez
# freq                                                    1            11
#
#          long_name         dob nationality          club player_positions
# count        18278       18278       18278         18278            18278  \
# unique       18218        6142         162           698              643
# top     Liam Kelly  1992-02-29     England  FC Barcelona               CB
# freq             3         113        1667            33             2322
#
#        preferred_foot      work_rate body_type  ...    lwb    ldm    cdm
# count           18278          18278     18278  ...  16242  16242  16242  \
# unique              2              9        10  ...     98     98     98
# ...

# %%
fifa_df.describe(include='all')
# Out:
#             sofifa_id                                         player_url
# count    18278.000000                                              18278  \
# unique            NaN                                              18278
# top               NaN  https://sofifa.com/player/158023/lionel-messi/...
# freq              NaN                                                  1
# mean    219738.864482                                                NaN
# std      27960.200461                                                NaN
# min        768.000000                                                NaN
# 25%     204445.500000                                                NaN
# 50%     226165.000000                                                NaN
# 75%     240795.750000                                                NaN
# max     252905.000000                                                NaN
#
#           short_name   long_name           age         dob     height_cm
# ...

# %% [markdown]
# ## Part II) Exploratory Data Analysis

# %% [markdown]
# ## Part II) A) Do Numerical Analysis of Columns

# %% [markdown]
# ### Analysis of age column

# %%
fifa_df['age'].min()
# Out:
# 16

# %%
fifa_df['age'].max()
# Out:
# 42

# %%
fifa_df['age'].mean()
# Out:
# 25.283291388554545

# %%
fifa_df['age'].median()
# Out:
# 25.0

# %%
fifa_df['age'].std()
# Out:
# 4.656964497822004

# %%
fifa_df['age'].var()
# Out:
# 21.687318333974556

# %%
fifa_df['age'].skew()
# Out:
# 0.38061976075931975

# %% [markdown]
# #### What is the range of age values?

# %%
# Histogram plot

# %%
plt.figure(figsize=(5,5))
sns.histplot(fifa_df['age'], bins=10, color='yellow')
plt.title('Histogram depicting range of age values')
plt.show()

# %%
# Distribution plot

# %%
plt.figure(figsize=(5,5))
sns.displot(fifa_df['age'], kind='kde', color='magenta')
plt.title('Density plot for age values')
plt.show()

# %% [markdown]
# #### Are there any extreme age values in data?

# %%
fifa_df['age'].quantile(0.10), fifa_df['age'].quantile(0.25), fifa_df['age'].quantile(0.50), fifa_df['age'].quantile(0.75), fifa_df['age'].quantile(0.90)
# Out:
# (19.0, 22.0, 25.0, 29.0, 32.0)

# %%
# Box plot

# %%
plt.figure(figsize=(5,5))
sns.boxplot(fifa_df['age'], orient='h', color='cyan')
plt.title('Box plot for age values')
plt.show()

# %%
# Conclusion

# %% [markdown]
# **Age** column is symmetrical as it has skweness of 0.38 which is in between of -0.5 to 0.5.
#
# - The minimum age value is 16 and maximum age value is 42.
# - The value of mean of age is 25.283 and median of age is 25.28 whereas standard deviation for age is 4.65 and variance of age column is 21.68.
# - Most of the age values falls in the range of 18-37.
# - 10% of age values are 19 and below.
# - 25% of age values are 22 and below.
# - 50% of age values are 25 and below.
# - 75% of age values are 29 and below.
# - 90% of age values are 32 and below.
# - There are very little extreme values.
#
# Age column could be a good predictor for overall analysis of data and it's relation with other columns should
# be explored further.

# %% [markdown]
# ## Part II) B) Do Categortical  Analysis of Columns

# %%
# Count values

# %%
fifa_df['preferred_foot'].value_counts().sort_values(ascending=True)
# Out:
# preferred_foot
# Left      4318
# Right    13960
# Name: count, dtype: int64

# %%
# Percentage of these count values

# %%
fifa_df['preferred_foot'].value_counts(normalize=True)*100
# Out:
# preferred_foot
# Right    76.375971
# Left     23.624029
# Name: proportion, dtype: float64

# %%
# Piechart

# %%
plt.figure(figsize=(4,4))
sizes=(76.37, 23.62)
plt.pie(sizes, labels=['Right','Left'], autopct='%1.2f%%')
plt.title('Pie chart showing preferred foot type of players')
plt.legend()
plt.show()

# %%
# Countplot

# %%
plt.figure(figsize=(4,4))
sns.countplot(x=fifa_df['preferred_foot'])
plt.xlabel('Preferred foot')
plt.title('Countplot of preferred foot types', y=1)
plt.show()

# %%
# To find no. of unique values

# %%
fifa_df['preferred_foot'].nunique()
# Out:
# 2

# %%
# To find what are those unique values

# %%
fifa_df['preferred_foot'].unique()
# Out:
# array(['Left', 'Right'], dtype=object)

# %%
# Conclusion

# %% [markdown]
# - Here, we have 2 types of preferred foot types: Right and Left.
# - As their are only 2 types, so this **preferred_foot** column has very low cardinality.
# - Use of right foot is done on large basis i.e., 76.38% as compared to left foot which is 23.63%.

# %% [markdown]
# ## Part II) C) Combine Numerical and Categorical columns for analysis

# %%
# Correlation of numerical and categorical data

# %%
data=fifa_df[['height_cm','weight_kg']].corr()
data
# Out:
#            height_cm  weight_kg
# height_cm   1.000000   0.768816
# weight_kg   0.768816   1.000000

# %%
# Heatmap

# %%
plt.figure(figsize=(4,4))
sns.heatmap(data, cmap='RdYlGn',annot=True, linewidth=1)
plt.title('Heatmap showing relation between weight and height of player', y=1)
plt.show()

# %%
# Scatterplot

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=fifa_df, x= 'weight_kg', y= 'height_cm', color='olive'  )
plt.title('Scatter plot showing relation between weight and height of player', y=1)
plt.show()

# %%
# Regplot

# %%
plt.figure(figsize=(4,4))
sns.regplot(data=fifa_df, x='weight_kg', y='height_cm', scatter_kws={'color':'teal'}, line_kws={'color':'brown'})
plt.title('Regplot showing relation between weight and height of player', y=1)
plt.show()

# %% [markdown]
# ## Part II) D) Add your own Questions

# %%
# Q1 What is relation between age and preferred foot type?
plt.figure(figsize=(5,5))
sns.displot(data=fifa_df, x='age', hue='preferred_foot')
plt.title('Distplot for age and preferred foot type')
plt.show()

# %%
# Q2 What is the preferred foot type according to differnt age and weight?
plt.figure(figsize=(10,4))
sns.barplot(data=fifa_df, x="age", y="weight_kg",hue='preferred_foot',errorbar=None)
plt.title('Bar plot for age and weight for different types of preferred foot')
plt.show()

# %%
# Q3 What is the count of the overall attribute as per preferred foot type?
plt.figure(figsize=(20,5))
sns.countplot(data=fifa_df, x='overall', hue='preferred_foot')
plt.title('Count plot for overall attribute as per preferred foot type')
plt.show()

# %% [markdown]
# # Part III) Data Cleaning

# %% [markdown]
# ## Part III) A) Handling Duplicate data

# %%
# Check shape of original data

# %%
fifa_df.shape
# Out:
# (18278, 104)

# %%
# Drop duplicate values and reset your index columns.

# %%
fifa_df.drop_duplicates(inplace=True, keep='first')
fifa_df
# Out:
#        sofifa_id                                         player_url
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...  \
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32  \
# ...

# %%
# Check shape after applying drop duplicates

# %%
fifa_df.shape
# Out:
# (18278, 104)

# %%
# Drop unnecessary columns

# %%
fifa_df=fifa_df.drop(columns=fifa_df.columns[fifa_df.columns.get_loc('team_jersey_number')+1:]) 
# As their are many columns and I want to delete all the columnc after 'team_jersey_number' column, so we have used these above 
# syntax
fifa_df.shape
# Out:
# (18278, 26)

# %%
# Conclusion

# %% [markdown]
# - When we applied drop duplicates, the shape didn't change which means that their are no duplicate values in data.
# - We have dropped many unnecessary columns from data due to which shape size changed from 104 to 26 columns.

# %% [markdown]
# ## Part III) B)  Handling Missing Values

# %%
# Apply isnull() function and find the sum of missing values in all columns.

# %%
fifa_df.isnull().sum()
# Out:
# sofifa_id                       0
# player_url                      0
# short_name                      0
# long_name                       0
# age                             0
# dob                             0
# height_cm                       0
# weight_kg                       0
# nationality                     0
# club                            0
# overall                         0
# potential                       0
# value_eur                       0
# wage_eur                        0
# player_positions                0
# preferred_foot                  0
# international_reputation        0
# weak_foot                       0
# skill_moves                     0
# work_rate                       0
# body_type                       0
# real_face                       0
# release_clause_eur           1298
# player_tags                 16779
# team_position                 240
# team_jersey_number            240
# dtype: int64

# %%
# Find missing value in % form.

# %%
fifa_df.isnull().sum()/len(fifa_df)*100
# Out:
# sofifa_id                    0.000000
# player_url                   0.000000
# short_name                   0.000000
# long_name                    0.000000
# age                          0.000000
# dob                          0.000000
# height_cm                    0.000000
# weight_kg                    0.000000
# nationality                  0.000000
# club                         0.000000
# overall                      0.000000
# potential                    0.000000
# value_eur                    0.000000
# wage_eur                     0.000000
# player_positions             0.000000
# preferred_foot               0.000000
# international_reputation     0.000000
# weak_foot                    0.000000
# skill_moves                  0.000000
# work_rate                    0.000000
# body_type                    0.000000
# real_face                    0.000000
# release_clause_eur           7.101433
# player_tags                 91.798884
# team_position                1.313054
# ...

# %% [markdown]
# - As 91.7% of values are missing in **player_tags** column, we will drop thhis column.

# %%
fifa_df.drop(columns=['player_tags'], inplace=True)

# %%
# Substitue values in missing columns using mean of each column

# %%
fifa_df['release_clause_eur'].fillna(fifa_df['release_clause_eur'].mean(), inplace=True)
#fifa_df['team_position'].fillna(fifa_df['team_position'].max(), inplace=True)
fifa_df['team_jersey_number'].fillna(fifa_df['team_jersey_number'].max(), inplace=True)

# %%
# Conclude your finding on missing values.

# %% [markdown]
# - As missing values are less than 30%, so we substituted these missing values by calculating mean/max values.

# %% [markdown]
# ## Part III) C) Handling Outliers

# %%
# Box plot

# %%
plt.figure(figsize=(4,4))
sns.boxplot(data=fifa_df['overall'], color='cyan', orient='h')
plt.title('Box plot for overall attribute')
plt.show()

# %%
# Violin plot

# %%
plt.figure(figsize=(4,4))
sns.violinplot(data=fifa_df['overall'], color='tomato', orient='h')
plt.title('Violin plot for overall attribute')
plt.show()

# %%
# Interquartile range (IQR)

# %%
Q1=fifa_df['overall'].quantile(0.25)
Q2=fifa_df['overall'].quantile(0.50)
Q3=fifa_df['overall'].quantile(0.75)
print('Q1:', Q1, '\tQ2:', Q2, '\tQ3:', Q3)
# Out:
# Q1: 62.0 	Q2: 66.0 	Q3: 71.0

# %%
IQR=Q3-Q1
print('IQR:', IQR)
# Out:
# IQR: 9.0

# %%
min_whisker = Q1-(1.5*IQR)
max_whisker = Q3+(1.5*IQR)
print('Minimum whisker:', min_whisker, '\tMaximum whisker:', max_whisker)
# Out:
# Minimum whisker: 48.5 	Maximum whisker: 84.5

# %%
# Based on your anlysis either drop extreme values or substitute them with more acceptable value.

# %% [markdown]
# - Here, we will drop the extreme values.

# %%
# Drop values
fifa_df = fifa_df[fifa_df['overall']>48.5]
fifa_df =fifa_df[fifa_df['overall']<84.5]
fifa_df
# Out:
#        sofifa_id                                         player_url
# 108       233049  https://sofifa.com/player/233049/jadon-sancho/...  \
# 109       235790  https://sofifa.com/player/235790/kai-havertz/2...
# 110       231443  https://sofifa.com/player/231443/ousmane-dembe...
# 111       206585  https://sofifa.com/player/206585/kepa-arrizaba...
# 112       210514  https://sofifa.com/player/210514/joao-pedro-ca...
# ...          ...                                                ...
# 18230     243107  https://sofifa.com/player/243107/lin-cui/20/15...
# 18231     251365  https://sofifa.com/player/251365/patryk-krolcz...
# 18232     243117  https://sofifa.com/player/243117/weijun-xie/20...
# 18233     182461  https://sofifa.com/player/182461/ting-zhou/20/...
# 18234     247775  https://sofifa.com/player/247775/junzhe-zhang/...
#
#          short_name                  long_name  age         dob  height_cm
# ...

# %%
# Conclusion

# %% [markdown]
# - Outliers have been deleted.

# %% [markdown]
# ## Part III) D) Handling Categorical Values

# %%
# Two types of categorical values : ordinal and nominal

# %%
fifa_df.describe(include='O')
# Out:
#                                                player_url    short_name
# count                                               18127         18127  \
# unique                                              18127         17219
# top     https://sofifa.com/player/233049/jadon-sancho/...  J. Rodríguez
# freq                                                    1            10
#
#          long_name         dob nationality        club player_positions
# count        18127       18127       18127       18127            18127  \
# unique       18067        6124         162         698              641
# top     Liam Kelly  1992-02-29     England  CD Leganés               CB
# freq             3         113        1652          33             2299
#
#        preferred_foot      work_rate body_type real_face team_position
# count           18127          18127     18127     18127         17887
# unique              2              9         5         2            29
# ...

# %% [markdown]
# - There are no ordinal values in the given dataset.

# %%
# Nominal

# %%
# One-hot encoding

# %% [markdown]
# - One-hot encoding can be applied on preferred_foot, body_type, real_face and team_position column. Let's apply it on 'real_face' column.

# %%
fifa_df = pd.get_dummies(fifa_df, columns=['real_face'])

# %%
fifa_df.head()
# Out:
#      sofifa_id                                         player_url
# 108     233049  https://sofifa.com/player/233049/jadon-sancho/...  \
# 109     235790  https://sofifa.com/player/235790/kai-havertz/2...
# 110     231443  https://sofifa.com/player/231443/ousmane-dembe...
# 111     206585  https://sofifa.com/player/206585/kepa-arrizaba...
# 112     210514  https://sofifa.com/player/210514/joao-pedro-ca...
#
#        short_name                  long_name  age         dob  height_cm
# 108     J. Sancho               Jadon Sancho   19  2000-03-25        180  \
# 109    K. Havertz                Kai Havertz   20  1999-06-11        188
# 110    O. Dembélé            Ousmane Dembélé   22  1997-05-15        178
# 111          Kepa          Kepa Arrizabalaga   24  1994-10-03        186
# 112  João Cancelo  João Pedro Cavaco Cancelo   25  1994-05-27        182
#
#      weight_kg nationality                 club  ...
# 108         76     England    Borussia Dortmund  ...  \
# ...

# %%
fifa_df.replace({False:0, True:1}, inplace=True)
fifa_df.head()
# Out:
#      sofifa_id                                         player_url
# 108     233049  https://sofifa.com/player/233049/jadon-sancho/...  \
# 109     235790  https://sofifa.com/player/235790/kai-havertz/2...
# 110     231443  https://sofifa.com/player/231443/ousmane-dembe...
# 111     206585  https://sofifa.com/player/206585/kepa-arrizaba...
# 112     210514  https://sofifa.com/player/210514/joao-pedro-ca...
#
#        short_name                  long_name  age         dob  height_cm
# 108     J. Sancho               Jadon Sancho   19  2000-03-25        180  \
# 109    K. Havertz                Kai Havertz   20  1999-06-11        188
# 110    O. Dembélé            Ousmane Dembélé   22  1997-05-15        178
# 111          Kepa          Kepa Arrizabalaga   24  1994-10-03        186
# 112  João Cancelo  João Pedro Cavaco Cancelo   25  1994-05-27        182
#
#      weight_kg nationality                 club  ...
# 108         76     England    Borussia Dortmund  ...  \
# ...

# %%
# Applying frequency encoding on high cardinality columns

# %%
fifa_df['work_rate'].value_counts()
# Out:
# work_rate
# Medium/Medium    9811
# High/Medium      3191
# Medium/High      1694
# High/High         968
# Medium/Low        877
# High/Low          679
# Low/Medium        459
# Low/High          415
# Low/Low            33
# Name: count, dtype: int64

# %%
fifa_df['nationality'].value_counts().head()
# Out:
# nationality
# England      1652
# Germany      1207
# Spain        1021
# France        972
# Argentina     879
# Name: count, dtype: int64

# %% [markdown]
# - As it's difficult for machines to interpret string values, so in this process we try to convert string values into numeric    values

# %% [markdown]
# ## Part III) E) Handling Numerical values

# %%
# Whether the data is symmetrical or not.

# %%
fifa_df['weight_kg'].skew()
# Out:
# 0.2183967643179262

# %% [markdown]
# - As skewness of weight_kg column is 0.2, which is between -0.5 to 0.5 so the given data is symmetrical.

# %%
# Plot histogram plot.

# %%
plt.figure(figsize=(4,4))
sns.histplot(fifa_df['weight_kg'], color='green', bins=10)
plt.title('Histogram plot for Weight')
plt.show()

# %%
# Plot distribution plot

# %%
plt.figure(figsize=(4,4))
sns.displot(fifa_df['weight_kg'], color='tomato', kind='kde')
plt.title('Distribution plot for Weight')
plt.show()

# %%
# If your data is not skewed and symmetrical apply standard scaler.

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
fifa_df[['weight_kg', 'height_cm']]=scaler.fit_transform(fifa_df[['weight_kg', 'height_cm']])

# %%
# Confirm the distribution patter by plotting histogram and distribution plot again.

# %%
# Weight
plt.figure(figsize=(4,4))
sns.histplot(x=fifa_df['weight_kg'],kde=True, color='green', bins=30)
plt.title('Histogram for weight')
plt.ylabel('Weight')
plt.show()

# %%
# Height
plt.figure(figsize=(4,4))
sns.histplot(x=fifa_df['height_cm'],kde=True, color='orange', bins=30)
plt.title('Histogram for Height')
plt.ylabel('Height')
plt.show()

# %%
# Conclusion

# %% [markdown]
# - From the above observation, we can say that **weight_kg** column is symetrical as it's skew value is 0.2 which is
#   between -0.5 to 0.5.
